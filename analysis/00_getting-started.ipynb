# %%
import sys, os

# %%
sys.path
# Out:
# ['/home/548/cd3022/repos/GC26-combined-solar-wind',
#  '/home/548/cd3022/ondemand/data/sys/dashboard/batch_connect/sys/jupyter/ncigadi/output/0a815419-e487-4819-83a7-0539335fb250/lib/python3',
#  '/g/data/xp65/public/apps/med_conda/envs/analysis3-25.11/lib/python311.zip',
#  '/g/data/xp65/public/apps/med_conda/envs/analysis3-25.11/lib/python3.11',
#  '/g/data/xp65/public/apps/med_conda/envs/analysis3-25.11/lib/python3.11/lib-dynload',
#  '',
#  '/home/548/cd3022/.local/lib/python3.11/site-packages',
#  '/g/data/xp65/public/apps/med_conda/envs/analysis3-25.11/lib/python3.11/site-packages']
